# %%
import os
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
cd /content/drive/MyDrive/Colab Notebooks/git
# Out:
# /content/drive/MyDrive/Colab Notebooks/git

# %%
# !git clone https://[Github 아이디]:[access token]@github.com/[Github 아이디]/[리포지토리 이름].git

# %%
# !git clone https://dudungE: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@github.com/dudungE/FIND_A_RiskyAssets1.git
# Out:
# Cloning into 'FIND_A_RiskyAssets1'...
# remote: Enumerating objects: 21, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 21 (delta 0), reused 14 (delta 0), pack-reused 0
# Unpacking objects: 100% (21/21), 4.01 MiB | 5.50 MiB/s, done.

# %%
cd /content/drive/MyDrive/Colab Notebooks/git/FIND_A_RiskyAssets1/curriculum/2-4 Portfolio Theory I
# Out:
# /content/drive/MyDrive/Colab Notebooks/git/FIND_A_RiskyAssets1/curriculum/2-4 Portfolio Theory I

# %%
# !git config --global user.email 'jjgus29@naveer.com'
# !git config --global user.name 'dudungE'

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	"\341\204\214\341\205\245\341\206\274\341\204\214\341\205\242\341\204\222\341\205\247\341\206\253/Untitled"
# 	"\341\204\214\341\205\245\341\206\274\341\204\214\341\205\242\341\204\222\341\205\247\341\206\253/test2.ipynb"
# 	../../git_drive.ipynb
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git add *

# %%
# !git commit -m "coloab to github test"
# Out:
# [main e6a6873] coloab to github test
#  7 files changed, 5022 insertions(+)
#  create mode 100644 "curriculum/2-4 Portfolio Theory I/\341\204\214\341\205\245\341\206\274\341\204\214\341\205\242\341\204\222\341\205\247\341\206\253/Correaltion_\341\204\211\341\205\256\341\204\213\341\205\265\341\206\250\341\204\205\341\205\262\341\206\257_last.ipynb"
#  create mode 100644 "curriculum/2-4 Portfolio Theory I/\341\204\214\341\205\245\341\206\274\341\204\214\341\205\242\341\204\222\341\205\247\341\206\253/base_optimal_port_KOR _234.ipynb"
#  create mode 100644 "curriculum/2-4 Portfolio Theory I/\341\204\214\341\205\245\341\206\274\341\204\214\341\205\242\341\204\222\341\205\247\341\206\253/base_optimal_port_kor.ipynb"
#  create mode 100644 "curriculum/2-4 Portfolio Theory I/\341\204\214\341\205\245\341\206\274\341\204\214\341\205\242\341\204\222\341\205\247\341\206\253/optimal_port_US_Index.ipynb"
# ...

# %%
# !git push
# Out:
# Enumerating objects: 9, done.
# Counting objects: 100% (9/9), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (6/6), 695 bytes | 86.00 KiB/s, done.
# Total 6 (delta 0), reused 0 (delta 0)
# To https://github.com/dudungE/FIND_A_RiskyAssets1.git
#    de86834..e6a6873  main -> main
